# %%
import ndlib
import networkx as nx
import matplotlib.pyplot as plt
import ndlib.models.ModelConfig as mc
import ndlib.models.opinions as op
import json
import warnings
from ndlib.viz.mpl.DiffusionTrend import DiffusionTrend
from ndlib.viz.mpl.OpinionEvolution import OpinionEvolution
# Out:
# no display found. Using non-interactive Agg backend
# no display found. Using non-interactive Agg backend

# %%
# %run Utilyties.ipynb
# %matplotlib inline
# Out:
# <style type="text/css">
# h1 {
#     color:#000;
#     font: 0 sans-serif;
#     border-top: 5px solid #CFB4A6;
#     padding-top: 10px;
#
# }
# table {
#     float:left
# }
# </style>

# %%
data = read_data('C:\\Users\\diego\OneDrive\\Desktop\\SNA_project\\notebook\\data\\data_complete.json')
#data = read_data('prova.json')

G = init_network(data)
# Out:
# Alcune informazioni iniziali sui dati sono:
# * TOT Retweet =  29863
# * TOT Quote =  1187
# * TOT Mentions =  57896
# * TOT Reply =  3000
# La rete è stara inizializzata correttamente

# %%
G0 = giant_component(G)

# %% [markdown]
# Creo il <b>Complete Graph H</b> da 3000 nodi casuali della G0

# %%
import random as rd 

sample = rd.sample(G0.nodes, 3000)
H = nx.complete_graph(sample)

#associo ad ogni nodo del Complete Graph la propra classificazione 
labels = nx.get_node_attributes(G0, 'classification') 
nx.set_node_attributes(H, labels, 'classification')

# %% [markdown]
# # Deffaunt Model

# %% [markdown]
# ## Prepocessing

# %%
#cambio il nome dei nodi per poterli passare a AlgorithmicBiasModel
mapping = dict(zip(G0, range(1, G0.number_of_nodes()+1)))
G0_l = nx.relabel_nodes(G0, mapping)
mapping = dict(zip(H, range(1, H.number_of_nodes()+1)))
H_l = nx.relabel_nodes(H, mapping)

# %% [markdown]
# ## Crawled Data - Real Opinion

# %% [markdown]
# <b>With bias</b>:
# - Gamma 0,5 con epsilon 0.65 e 1.3
# - Gamma 1 con epsilon 0.65 e 1.3
# - Gamma 1,5 con epsilon 0.65 e 1.3
# - Gamma 5 con epsilon 0.65 e 1.3

# %% [markdown]
# ### Gamma = 0.5

# %% [markdown]
# ##### Epsilon = 0.65

# %%
model = op.AlgorithmicBiasModel(G0_l)

# Model configuration
config = mc.Configuration()
config.add_model_parameter("epsilon", 0.65)
config.add_model_parameter("gamma", 0.5)  
model.set_initial_status(config)

# Simulation execution
iterations = model.iteration_bunch(500) #1000

plt.figure(figsize=(8,5))
viz = OpinionEvolution(model, iterations)
viz.plot()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 500/500 [17:25<00:00,  2.09s/it]
# No handles with labels found to put in legend.

# %% [markdown]
# #### Epsilon = 1.3

# %%
model = op.AlgorithmicBiasModel(G0_l)

# Model configuration
config = mc.Configuration()
config.add_model_parameter("epsilon", 1.3)
config.add_model_parameter("gamma", 0.5)  
model.set_initial_status(config)

# Simulation execution
iterations = model.iteration_bunch(500)#1000

plt.figure(figsize=(8,5))
viz = OpinionEvolution(model, iterations)
viz.plot()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 500/500 [17:07<00:00,  2.05s/it]
# No handles with labels found to put in legend.

# %% [markdown]
# ### Gamma = 1

# %% [markdown]
# ##### Epsilon = 0.65

# %%
model = op.AlgorithmicBiasModel(G0_l)

# Model configuration
config = mc.Configuration()
config.add_model_parameter("epsilon", 0.65)
config.add_model_parameter("gamma", 1)  
model.set_initial_status(config)

# Simulation execution
iterations = model.iteration_bunch(500)

plt.figure(figsize=(8,5))
viz = OpinionEvolution(model, iterations)
viz.plot()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 500/500 [18:12<00:00,  2.19s/it]
# No handles with labels found to put in legend.

# %% [markdown]
# #### Epsilon = 1.3

# %%
model = op.AlgorithmicBiasModel(G0_l)

# Model configuration
config = mc.Configuration()
config.add_model_parameter("epsilon", 1.3)
config.add_model_parameter("gamma", 1)  
model.set_initial_status(config)

# Simulation execution
iterations = model.iteration_bunch(500)

plt.figure(figsize=(8,5))
viz = OpinionEvolution(model, iterations)
viz.plot()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 500/500 [17:24<00:00,  2.09s/it]
# No handles with labels found to put in legend.

# %% [markdown]
# ### Gamma = 1.5

# %% [markdown]
# ##### Epsilon = 0.65

# %%
model = op.AlgorithmicBiasModel(G0_l)

# Model configuration
config = mc.Configuration()
config.add_model_parameter("epsilon", 0.65)
config.add_model_parameter("gamma", 1.5)  
model.set_initial_status(config)

# Simulation execution
iterations = model.iteration_bunch(500)

plt.figure(figsize=(8,5))
viz = OpinionEvolution(model, iterations)
viz.plot()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 500/500 [18:41<00:00,  2.24s/it]
# No handles with labels found to put in legend.

# %% [markdown]
# #### Epsilon = 1.3

# %%
model = op.AlgorithmicBiasModel(G0_l)

# Model configuration
config = mc.Configuration()
config.add_model_parameter("epsilon", 1.3)
config.add_model_parameter("gamma", 1.5)  
model.set_initial_status(config)

# Simulation execution
iterations = model.iteration_bunch(500)

plt.figure(figsize=(8,5))
viz = OpinionEvolution(model, iterations)
viz.plot()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 500/500 [17:29<00:00,  2.10s/it]
# No handles with labels found to put in legend.

# %% [markdown]
# ### Gamma = 5

# %% [markdown]
# ##### Epsilon = 0.65

# %%
model = op.AlgorithmicBiasModel(G0_l)

# Model configuration
config = mc.Configuration()
config.add_model_parameter("epsilon", 0.65)
config.add_model_parameter("gamma", 5)  
model.set_initial_status(config)

# Simulation execution
iterations = model.iteration_bunch(250)

plt.figure(figsize=(8,5))
viz = OpinionEvolution(model, iterations)
viz.plot()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 250/250 [09:06<00:00,  2.19s/it]
# No handles with labels found to put in legend.

# %% [markdown]
# #### Epsilon = 1.3

# %%
model = op.AlgorithmicBiasModel(G0_l)

# Model configuration
config = mc.Configuration()
config.add_model_parameter("epsilon", 1.3)
config.add_model_parameter("gamma", 5)  
model.set_initial_status(config)

# Simulation execution
iterations = model.iteration_bunch(250)

plt.figure(figsize=(8,5))
viz = OpinionEvolution(model, iterations)
viz.plot()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 250/250 [10:16<00:00,  2.47s/it]
# No handles with labels found to put in legend.

# %% [markdown]
# <b>W/O bias</b>:
# - con epsilon 0.65 e 1.3

# %% [markdown]
# ### Gamma = 0

# %% [markdown]
# ##### Epsilon = 0.65

# %%
model = op.AlgorithmicBiasModel(G0_l)

# Model configuration
config = mc.Configuration()
config.add_model_parameter("epsilon", 0.65)
config.add_model_parameter("gamma", 0)  
model.set_initial_status(config)

# Simulation execution
iterations = model.iteration_bunch(100)

plt.figure(figsize=(8,5))
viz = OpinionEvolution(model, iterations)
viz.plot()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [04:17<00:00,  2.57s/it]
# No handles with labels found to put in legend.

# %% [markdown]
# #### Epsilon = 1.3

# %%
model = op.AlgorithmicBiasModel(G0_l)

# Model configuration
config = mc.Configuration()
config.add_model_parameter("epsilon", 1.3)
config.add_model_parameter("gamma", 0)  
model.set_initial_status(config)

# Simulation execution
iterations = model.iteration_bunch(100)

plt.figure(figsize=(8,5))
viz = OpinionEvolution(model, iterations)
viz.plot()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [04:21<00:00,  2.62s/it]
# No handles with labels found to put in legend.

# %% [markdown]
# ## Mean field model

# %% [markdown]
# <b>With bias</b>:
# - Gamma 0,5 con epsilon 0.65 e 1.3
# - Gamma 1 con epsilon 0.65 e 1.3
# - Gamma 1,5 con epsilon 0.65 e 1.3
# - Gamma 5 con epsilon 0.65 e 1.3
#
#
# <b>Without bias</b>:
# - Gamma 0,5 con epsilon 0.65

# %% [markdown]
# ### Gamma = 0.5

# %% [markdown]
# #### Epsilon = 0.65

# %%
model = op.AlgorithmicBiasModel(H_l)

# Model configuration
config = mc.Configuration()
config.add_model_parameter("epsilon", 0.65)
config.add_model_parameter("gamma", 0.5)  # No bias = Deffuant
model.set_initial_status(config)

# Simulation execution
iterations = model.iteration_bunch(25)

plt.figure(figsize=(8,5))
viz = OpinionEvolution(model, iterations)
viz.plot()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [10:41<00:00, 25.65s/it]
# No handles with labels found to put in legend.

# %% [markdown]
# #### Epsilon = 1.3

# %%
model = op.AlgorithmicBiasModel(H_l)

# Model configuration
config = mc.Configuration()
config.add_model_parameter("epsilon", 1.3)
config.add_model_parameter("gamma", 0.5)  # No bias = Deffuant
model.set_initial_status(config)

# Simulation execution
iterations = model.iteration_bunch(25)

plt.figure(figsize=(8,5))
viz = OpinionEvolution(model, iterations)
viz.plot()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [09:48<00:00, 23.54s/it]
# No handles with labels found to put in legend.

# %% [markdown]
# ### Gamma = 1

# %% [markdown]
# #### Epsilon = 0.65

# %%
model = op.AlgorithmicBiasModel(H_l)

# Model configuration
config = mc.Configuration()
config.add_model_parameter("epsilon", 0.65)
config.add_model_parameter("gamma", 1)  # No bias = Deffuant
model.set_initial_status(config)

# Simulation execution
iterations = model.iteration_bunch(100)

plt.figure(figsize=(8,5))
viz = OpinionEvolution(model, iterations)
viz.plot()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [45:17<00:00, 27.18s/it]
# No handles with labels found to put in legend.

# %% [markdown]
# #### Epsilon = 1.3

# %%
model = op.AlgorithmicBiasModel(H_l)

# Model configuration
config = mc.Configuration()
config.add_model_parameter("epsilon", 1.3)
config.add_model_parameter("gamma", 1)  # No bias = Deffuant
model.set_initial_status(config)

# Simulation execution
iterations = model.iteration_bunch(100)

plt.figure(figsize=(8,5))
viz = OpinionEvolution(model, iterations)
viz.plot()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [44:54<00:00, 26.95s/it]
# No handles with labels found to put in legend.

# %% [markdown]
# ### Gamma = 1.5

# %% [markdown]
# #### Epsilon = 0.65

# %%
model = op.AlgorithmicBiasModel(H_l)

# Model configuration
config = mc.Configuration()
config.add_model_parameter("epsilon", 0.65)
config.add_model_parameter("gamma", 1.5)  # No bias = Deffuant
model.set_initial_status(config)

# Simulation execution
iterations = model.iteration_bunch(100)

plt.figure(figsize=(8,5))
viz = OpinionEvolution(model, iterations)
viz.plot()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [39:14<00:00, 23.54s/it]
# No handles with labels found to put in legend.

# %% [markdown]
# #### Epsilon = 1.3

# %%
model = op.AlgorithmicBiasModel(H_l)

# Model configuration
config = mc.Configuration()
config.add_model_parameter("epsilon", 1.3)
config.add_model_parameter("gamma", 1.5)  # No bias = Deffuant
model.set_initial_status(config)

# Simulation execution
iterations = model.iteration_bunch(50)

plt.figure(figsize=(8,5))
viz = OpinionEvolution(model, iterations)
viz.plot()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [19:22<00:00, 23.25s/it]
# No handles with labels found to put in legend.

# %% [markdown]
# ### Gamma =5

# %% [markdown]
# #### Epsilon=0.65

# %%
model = op.AlgorithmicBiasModel(H_l)

# Model configuration
config = mc.Configuration()
config.add_model_parameter("epsilon", 0.65)
config.add_model_parameter("gamma", 5)  # No bias = Deffuant
model.set_initial_status(config)

# Simulation execution
iterations = model.iteration_bunch(100)

plt.figure(figsize=(8,5))
viz = OpinionEvolution(model, iterations)
viz.plot()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [43:43<00:00, 26.24s/it]
# No handles with labels found to put in legend.

# %% [markdown]
# #### Epsilon=1.3

# %%
model = op.AlgorithmicBiasModel(H_l)

# Model configuration
config = mc.Configuration()
config.add_model_parameter("epsilon", 1.3)
config.add_model_parameter("gamma", 5)  # No bias = Deffuant
model.set_initial_status(config)

# Simulation execution
iterations = model.iteration_bunch(100)

plt.figure(figsize=(8,5))
viz = OpinionEvolution(model, iterations)
viz.plot()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [51:13<00:00, 30.74s/it]
# No handles with labels found to put in legend.

# %% [markdown]
# ### Gamma = 0

# %% [markdown]
# #### Epsilon = 0.65

# %%
model = op.AlgorithmicBiasModel(H_l)

# Model configuration
config = mc.Configuration()
config.add_model_parameter("epsilon", 0.65)
config.add_model_parameter("gamma", 0)  # No bias = Deffuant
model.set_initial_status(config)

# Simulation execution
iterations = model.iteration_bunch(25)

plt.figure(figsize=(8,5))
viz = OpinionEvolution(model, iterations)
viz.plot()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [10:28<00:00, 25.13s/it]
# No handles with labels found to put in legend.

# %% [markdown]
# #### Epsilon = 1.3

# %%
model = op.AlgorithmicBiasModel(H_l)

# Model configuration
config = mc.Configuration()
config.add_model_parameter("epsilon", 1.3)
config.add_model_parameter("gamma", 0)  # No bias = Deffuant
model.set_initial_status(config)

# Simulation execution
iterations = model.iteration_bunch(25)

plt.figure(figsize=(8,5))
viz = OpinionEvolution(model, iterations)
viz.plot()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [10:03<00:00, 24.13s/it]
# No handles with labels found to put in legend.
